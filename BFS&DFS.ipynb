# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya3218/data_science_lab_SE_02/blob/main/BFS%26DFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#BFS
from collections import deque

def bfs(graph, start_node):
    visited = set()
    queue = deque([start_node])
    traversal_order = []

    visited.add(start_node)

    while queue:
        current_node = queue.popleft()
        traversal_order.append(current_node)

        for neighbor in graph[current_node]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)
    return traversal_order

# Define a sample graph using an adjacency list
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}

start_node = 'A'
print(f"BFS Traversal starting from node {start_node}: {bfs(graph, start_node)}")
# Out:
# BFS Traversal starting from node A: ['A', 'B', 'C', 'D', 'E', 'F']

# %%
#DFS
def dfs(graph, start_node, visited=None):
    if visited is None:
        visited = set()
    traversal_order = []

    def _dfs_recursive(node):
        visited.add(node)
        traversal_order.append(node)
        for neighbor in graph[node]:
            if neighbor not in visited:
                _dfs_recursive(neighbor)

    _dfs_recursive(start_node)
    return traversal_order

# Using the same graph as BFS
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}

start_node = 'A'
print(f"DFS Traversal starting from node {start_node}: {dfs(graph, start_node)}")
# Out:
# DFS Traversal starting from node A: ['A', 'B', 'D', 'E', 'F', 'C']
